# %%
# %load_ext autoreload
# %autoreload 2

# %env TORCH_HOME=/mnt/home/mizrahiulysse/model_cache/torch
# %env HF_HOME=/mnt/home/mizrahiulysse/huggingface

from elasticdino.training.dpt import DPTHead, DPTDepthModel
from elasticdino.model.dino import DinoV2
import torchvision
import torch
from PIL import Image
# Out:
# env: TORCH_HOME=/mnt/home/mizrahiulysse/model_cache/torch

# %%
# import tempfile
# tempfile.tempdir = "/mnt/home/mizrahiulysse/tmp/"

from elasticdino.data.imagenet import load_imagenet
# Out:
# Loading imagenet
# Imagenet loaded
# /mnt/projects/conda-envs/dgxenv-2024-12-31-09-55-46-x4057-centos9-py310-pt251cf/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
from elasticdino.training.dpt import DPTHead
from elasticdino.training.depth.layers import DPTDepthModel
from elasticdino.training.depth.train import make_pretraining_dataloader, train_depth
import torch.nn as nn

dataloader = load_imagenet("/mnt/home/mizrahiulysse/datasets/imagenet-1k-256/imagenet/test", 32, image_size=128)

dino = DinoV2("l")
model = DPTDepthModel(128, dino, 128).to("cuda")
# model = nn.DataParallel(DPTDepthModel(128, dino, 128)).to("cuda:0")
# dataloader = load_imagenet("/mnt/home/mizrahiulysse/datasets/imagenet-1k-256/imagenet/train", 8, image_size=128)
depth_dataloader = make_pretraining_dataloader(dataloader, "/mnt/home/mizrahiulysse/model_cache/depth_anything_v2_large/", True)

train_depth(
          "/mnt/home/mizrahiulysse/elasticdino-runs/pretrain-elasticdino-depth/dpt",
          depth_dataloader,
          model,
          n_epochs=200,
          max_iterations=20,
          lr = 1e-4,
          decay_period=5000,
          accumulation=1,
          debug_interval=10,
          save_interval=5,
          display_size=128)
# Out:
# Loading imagenet
# Imagenet loaded
# Using cache found in /mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main
# Start training
# Epoch 0
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# loss
# back
# batch
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 4, 1024, 16, 16])
# ...

# %%
# !nvidia-smi
