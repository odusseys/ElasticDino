# %%
# %load_ext autoreload 
# %autoreload 2

# %%
from elasticdino.training.ablations import train_depth, AblateDeformations, AblationTaskHeads, HypersimTaskHeads
from elasticdino.data.hypersim_depth import get_hypersim_datasets
from elasticdino.model.elasticdino import ElasticDino
import torch
import os

hypersim_path = "/mnt/home/mizrahiulysse/datasets/hypersim-depth"
   
model_config = dict(
    dino_model="b",
    n_features_in=768,
    layers={
        32: dict(hidden_features=256, n_blocks=4, layers_per_block=4),
        64: dict(hidden_features=256, n_blocks=4, layers_per_block=3),
        128: dict(hidden_features=128, n_blocks=4, layers_per_block=2),
    },
    start_size=32,
    target_size=128,
)

dino_repo = "/mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main"

def get_model(ablation):
    def get_ablated():
        if ablation == "heads":
            return ElasticDino(model_config, dino_repo)
        elif ablation == "deformations":
            return AblateDeformations(model_config, dino_repo)
        elif ablation == "none":
            return ElasticDino(model_config, dino_repo)
        else:
            raise Exception("Unknown ablation")
    
    return get_ablated


ablation = "heads"

project_folder=f"/mnt/home/mizrahiulysse/elasticdino-runs/ablations-eval/{ablation}"

checkpoints = dict(
    heads=f"/mnt/home/mizrahiulysse/elasticdino-runs/ablations/heads/2025-01-29-06:15:35/checkpoints/60000/model.safetensors",
    deformations=f"/mnt/home/mizrahiulysse/elasticdino-runs/ablations/deformations/2025-01-29-05:45:20/60000/model.safetensors",
    none=f"/mnt/home/mizrahiulysse/elasticdino-runs/ablations/none/2025-01-29-05:44:35/checkpoints/60000/model.safetensors",
)

train_config = dict(
  n_epochs=50,
#   max_iterations=2,
  lr = 1e-3,
  debug_interval=100,
  n_features=64,
  save_interval=1000,
  batch_size=32,
  use_blur_loss=False,
  project_folder=project_folder,
  checkpoint=checkpoints[ablation]
)

def get_dataloaders():
    train, val = get_hypersim_datasets(hypersim_path)
    return torch.utils.data.DataLoader(train, batch_size=train_config["batch_size"], shuffle=False, num_workers=32), torch.utils.data.DataLoader(val, batch_size=train_config["batch_size"], shuffle=False, num_workers=32), 


args = (train_config, model_config, get_model(ablation), get_dataloaders)

from accelerate import notebook_launcher

notebook_launcher(
  train_depth,
  args,
  num_processes=2
)
# Out:
# Launching training on 2 GPUs.
# /mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# /mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:33: UserWarning: xFormers is available (Block)
#   warnings.warn("xFormers is available (Block)")
# INFO:dinov2:using MLP layer as FFN
# /mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# /mnt/home/mizrahiulysse/model_cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:33: UserWarning: xFormers is available (Block)
#   warnings.warn("xFormers is available (Block)")
# INFO:dinov2:using MLP layer as FFN
# Epoch 1
# 100 6.107068343539204
# <PIL.Image.Image image mode=RGB size=512x128>
# 200 2.832965137037242
# <PIL.Image.Image image mode=RGB size=512x128>
# W0217 06:16:09.275000 1832181 site-packages/torch/distributed/elastic/agent/server/api.py:704] Received Signals.SIGINT death signal, shutting down workers
# Process Process-5:5:
# Process Process-5:25:
# Process Process-5:10:
# Process Process-6:27:
# Process Process-5:23:
# Process Process-5:30:
# Process Process-6:11:
# Process Process-5:6:
# W0217 06:16:09.280000 1832181 site-packages/torch/distributed/elastic/multiprocessing/api.py:766] Closing process 1999242 via signal SIGINT
# Process Process-5:18:
# Process Process-5:28:
# W0217 06:16:09.283000 1832181 site-packages/torch/distributed/elastic/multiprocessing/api.py:766] Closing process 1999243 via signal SIGINT
# Process Process-6:10:
# Process Process-5:32:
# Process Process-5:26:
# Process Process-5:8:
# Process Process-5:16:
# Process Process-5:31:
# Process Process-5:3:
# Process Process-5:27:
# Process Process-5:2:
# Process Process-5:15:
# Process Process-5:20:
# Process Process-6:13:
# Process Process-5:11:
# Process Process-5:21:
# Process Process-6:17:
# Process Process-6:19:
# Process Process-6:32:
# Process Process-5:29:
# Process Process-5:24:
# Process Process-6:30:
# Traceback (most recent call last):
# Process Process-5:22:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2e58ee6560>
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2e58ee6560>  File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
# Traceback (most recent call last):
#
#
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1604, in __del__
# Traceback (most recent call last):
#
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1568, in _shutdown_workers
#     self._shutdown_workers()    self._shutdown_workers()
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1568, in _shutdown_workers
# w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)  File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/multiprocessing/process.py", line 149, in join
#
#         res = self._popen.wait(timeout)  File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/multiprocessing/process.py", line 149, in join
# res = self._popen.wait(timeout)  File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#
#
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#         if not wait([self.sentinel], timeout):
#
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/selectors.py", line 416, in select
# ready = selector.select(timeout)
# fd_event_list = self._selector.poll(timeout)
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/selectors.py", line 416, in select
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/elastic/multiprocessing/api.py", line 84, in _terminate_process_handler
#         fd_event_list = self._selector.poll(timeout)raise SignalException(f"Process {os.getpid()} got signal: {sigval}", sigval=sigval)
#
#   File "/mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/elastic/multiprocessing/api.py", line 84, in _terminate_process_handler
# torch.distributed.elastic.multiprocessing.api.    SignalExceptionraise SignalException(f"Process {os.getpid()} got signal: {sigval}", sigval=sigval)
# : Process 1999243 got signal: 2torch.distributed.elastic.multiprocessing.api
# .SignalException: if not wait([self.sentinel], timeout):Process 1999242 got signal: 2
# ---------------------------------------------------------------------------
# SignalException                           Traceback (most recent call last)
# Cell In[4], line 69
#      65 args = (train_config, model_config, get_model(ablation), get_dataloaders)
#      67 from accelerate import notebook_launcher
# ---> 69 notebook_launcher(
#      70   train_depth,
#      71   args,
#      72   num_processes=2
#      73 )
#
# File /mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/accelerate/launchers.py:244, in notebook_launcher(function, args, num_processes, mixed_precision, use_port, master_addr, node_rank, num_nodes, rdzv_backend, rdzv_endpoint, rdzv_conf, rdzv_id, max_restarts, monitor_interval, log_line_prefix_template)
#     242     if is_torch_version(">=", ELASTIC_LOG_LINE_PREFIX_TEMPLATE_PYTORCH_VERSION):
#     243         launch_config_kwargs["log_line_prefix_template"] = log_line_prefix_template
# --> 244     elastic_launch(config=LaunchConfig(**launch_config_kwargs), entrypoint=function)(*args)
#     245 except ProcessRaisedException as e:
#     246     if "Cannot re-initialize CUDA in forked subprocess" in e.args[0]:
#
# File /mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/launcher/api.py:138, in elastic_launch.__call__(self, *args)
#     137 def __call__(self, *args):
# --> 138     return launch_agent(self._config, self._entrypoint, list(args))
#
# File /mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/launcher/api.py:260, in launch_agent(config, entrypoint, args)
#     257 try:
#     258     metrics.initialize_metrics(metrics.MetricsConfig(config.metrics_cfg))
# --> 260     result = agent.run()
#     261     # records that agent.run() has succeeded NOT that workers have succeeded
#     262     events.record(agent.get_event_succeeded())
#
# File /mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/elastic/metrics/api.py:137, in prof.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     135 try:
#     136     start = time.time()
# --> 137     result = f(*args, **kwargs)
#     138     put_metric(f"{key}.success", 1, group)
#     139 except Exception:
#
# File /mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/elastic/agent/server/api.py:696, in SimpleElasticAgent.run(self, role)
#     694 shutdown_called: bool = False
#     695 try:
# --> 696     result = self._invoke_run(role)
#     697     self._total_execution_time = int(time.monotonic() - start_time)
#     698     self._record_metrics(result)
#
# File /mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/elastic/agent/server/api.py:855, in SimpleElasticAgent._invoke_run(self, role)
#     853 while True:
#     854     assert self._worker_group.state != WorkerState.INIT
# --> 855     time.sleep(monitor_interval)
#     856     run_result = self._monitor_workers(self._worker_group)
#     857     state = run_result.state
#
# File /mnt/projects/conda-envs/dgxenv-2025-02-14-14-28-13-x8619-centos9-py310-pt251cf/lib/python3.10/site-packages/torch/distributed/elastic/multiprocessing/api.py:84, in _terminate_process_handler(signum, frame)
#      75 """Termination handler that raises exceptions on the main process.
#      76
#      77 When the process receives death signal(SIGTERM, SIGINT), this termination handler will
#    (...)
#      81 be terminated.
#      82 """
#      83 sigval = signal.Signals(signum)
# ---> 84 raise SignalException(f"Process {os.getpid()} got signal: {sigval}", sigval=sigval)
#
# SignalException: Process 1832181 got signal: 2
